# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('combinedData.csv')

# %%
info = {
    "shape" : df.shape,
    "columns" : df.columns.tolist(),
    "dtypes" : df.dtypes.astype(str).to_dict(),
    "sampleData" : df.head().to_dict(orient = 'records')
}

# %%
print("dataset info : ")
for key, value in info.items():
  print(f"{key} : {value}\n")
# Out:
# dataset info :
# shape : (53043, 3)
#
# columns : ['Unnamed: 0', 'statement', 'status']
#
# dtypes : {'Unnamed: 0': 'int64', 'statement': 'object', 'status': 'object'}
#
# sampleData : [{'Unnamed: 0': 0, 'statement': 'oh my gosh', 'status': 'Anxiety'}, {'Unnamed: 0': 1, 'statement': 'trouble sleeping, confused mind, restless heart. All out of tune', 'status': 'Anxiety'}, {'Unnamed: 0': 2, 'statement': 'All wrong, back off dear, forward doubt. Stay in a restless and restless place', 'status': 'Anxiety'}, {'Unnamed: 0': 3, 'statement': "I've shifted my focus to something else but I'm still worried", 'status': 'Anxiety'}, {'Unnamed: 0': 4, 'statement': "I'm restless and restless, it's been a month now, boy. What do you mean?", 'status': 'Anxiety'}]

# %%
uniqueStatus = df['status'].unique().tolist()
print(f"unique mental health categories:\n{uniqueStatus}\n")
# Out:
# unique mental health categories:
# ['Anxiety', 'Normal', 'Depression', 'Suicidal', 'Stress', 'Bipolar', 'Personality disorder']

# %%
classDistribution = df['status'].value_counts().to_dict()
print("classDistribution: ")
for cls, count in classDistribution.items():
  print(f"{cls}: {count}")
# Out:
# classDistribution:
# Normal: 16351
# Depression: 15404
# Suicidal: 10653
# Anxiety: 3888
# Bipolar: 2877
# Stress: 2669
# Personality disorder: 1201

# %%
# Plot class distribution
plt.figure(figsize=(10, 6))
df["status"].value_counts().plot(
    kind="bar",
    color=["#4CAF50", "#2196F3", "#FF9800", "#F44336", "#9C27B0", "#00BCD4", "#795548"],
    edgecolor="black"
)
plt.title("Class Distribution in Mental Health Dataset", fontsize=14, fontweight="bold")
plt.xlabel("Mental Health Category", fontsize=12)
plt.ylabel("Number of Statements", fontsize=12)
plt.xticks(rotation=30, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
